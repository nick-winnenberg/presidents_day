# %% [markdown]
# # U.S. Presidents and Macroeconomic Indicators
#
# This notebook combines presidential term dates with FRED macroeconomic indicators.
#
# ## What this notebook does
# - Loads presidential term data from `presidents.csv`
# - Pulls annualized macro data from FRED
# - Computes start/end term values, percent/absolute changes, and annualized changes
# - Produces ranked comparison tables by metric
# - Exports styled ranked tables to PNG files
#
# ## Repeatable run order
# Run code cells in order from top to bottom. For a clean rerun, use **Restart Kernel and Run All**.
#
# ## Notes
# - Some indicators begin in later years, so earlier presidents can have missing values.
# - Exported images are written to the `exports/` folder.

# %%
from pathlib import Path

import pandas as pd
import numpy as np
import pandas_datareader as pdr

TOP_N = 5
EXPORT_DIR = Path("exports")
TABLE_CONVERSION = "matplotlib"

# %% [markdown]
# ## 1) Load presidential terms

# %%
p_df = pd.read_csv('presidents.csv')
p_df["Starting Year"] = p_df["Term"].astype(str).str.extract(r"(\d{4})")[0].astype("Int64")
p_df["Ending Year"] = p_df["Term"].astype(str).str.extract(r"(\d{4})$")[0].astype("Int64")
p_df.insert(
    p_df.columns.get_loc("Ending Year") + 1,
    "Term Length",
    (p_df["Ending Year"] - p_df["Starting Year"]).astype("Int64"),
)
p_df
# Out:
#     No.                 Name               Birthplace Birthday        Life  \
# 0     1    George Washington         Pope's Creek, VA   22-Feb   1732-1799
# 1     2           John Adams            Braintree, MA   30-Oct   1735-1826
# 2     3     Thomas Jefferson     Goochland County, VA   13-Apr   1743-1826
# 3     4        James Madison          Port Conway, VA   16-Mar   1751-1836
# 4     5         James Monroe          Monroe Hall, VA   28-Apr   1758-1831
# 5     6    John Quincy Adams            Braintree, MA   11-Jul   1767-1848
# 6     7       Andrew Jackson               Waxhaw, NC   15-Mar   1767-1845
# 7     8     Martin van Buren           Kinderhook, NY    5-Dec   1782-1862
# 8     9  William H. Harrison  Charles City County, VA    9-Feb   1773-1841
# 9    10           John Tyler  Charles City County, VA   29-Mar   1790-1862
# 10   11        James K. Polk            Pineville, NC    2-Nov   1795-1849
# 11   12       Zachary Taylor        Barboursville, VA   24-Nov   1784-1850
# 12   13     Millard Fillmore              Moravia, NY    7-Jan   1800-1874
# 13   14      Franklin Pierce         Hillsborough, NH   23-Nov   1804-1869
# 14   15       James Buchanan             Cove Gap, PA   23-Apr   1791-1868
# 15   16      Abraham Lincoln        Hardin County, KY   12-Feb   1809-1865
# 16   17       Andrew Johnson              Raleigh, NC   29-Dec   1808-1875
# 17   18     Ulysses S. Grant       Point Pleasant, OH   27-Apr   1822-1885
# 18   19     Rutherford Hayes             Delaware, OH    4-Oct   1822-1893
# 19   20       James Garfield       Moreland Hills, OH   19-Nov   1831-1881
# 20   21       Chester Arthur            Fairfield, VT    5-Oct   1829-1886
# 21   22     Grover Cleveland             Caldwell, NJ   18-Mar   1837-1908
# 22   23    Benjamin Harrison           North Bend, OH   20-Aug   1833-1901
# 23   24     Grover Cleveland             Caldwell, NJ   18-Mar   1837-1908
# 24   25     William McKinley                Niles, OH   29-Jan   1843-1901
# 25   26   Theodore Roosevelt        New York City, NY   27-Oct   1858-1919
# 26   27         William Taft           Cincinnati, OH   15-Sep   1857-1930
# 27   28       Woodrow Wilson             Staunton, VA   28-Dec   1856-1924
# 28   29       Warren Harding       Blooming Grove, OH    2-Nov   1865-1923
# 29   30      Calvin Coolidge             Plymouth, VT    4-Jul   1872-1933
# 30   31    Herbert C. Hoover          West Branch, IA   10-Aug   1874-1964
# 31   32   Franklin Roosevelt            Hyde Park, NY   30-Jan   1882-1945
# 32   33       Harry S Truman                Lamar, MO    8-May   1884-1972
# 33   34    Dwight Eisenhower              Denison, TX   14-Oct   1890-1969
# 34   35      John F. Kennedy            Brookline, MA   29-May   1917-1963
# 35   36       Lyndon Johnson            Stonewall, TX   27-Aug   1908-1973
# 36   37        Richard Nixon          Yorba Linda, CA    9-Jan   1913-1994
# 37   38       Gerald R. Ford                Omaha, NE   14-Jul  1913- 2006
# 38   39         Jimmy Carter               Plains, GA    1-Oct  1924-2024
# 39   40        Ronald Reagan              Tampico, IL    6-Feb  1911- 2004
# 40   41    George H. W. Bush               Milton, MA   12-Jun  1924- 2018
# 41   42         Bill Clinton                 Hope, AR   19-Aug      1946-
# 42   43       George W. Bush            New Haven, CT    6-Jul      1946-
# 43   44         Barack Obama             Honolulu, HI    4-Aug      1961-
# 44   45         Donald Trump     Queens, New York, NY   14-Jun       1946-
# 45   46            Joe Biden             Scranton, PA   20-Nov       1942-
# 46   47         Donald Trump     Queens, New York, NY   14-Jun       1946-
#
#     Height  Children                     Religion  \
# 0     1.88         0                 Episcopalian
# 1     1.70         5                    Unitarian
# 2     1.89         6       unaffiliated Christian
# 3     1.63         0                 Episcopalian
# 4     1.83         2                 Episcopalian
# 5     1.70         4                    Unitarian
# 6     1.85         0                 Presbyterian
# 7     1.68         4               Dutch Reformed
# 8     1.73         1                 Episcopalian
# 9     1.83         1                 Episcopalian
# 10    1.73         0                 Presbyterian
# 11    1.73         6                 Episcopalian
# 12    1.75         2                    Unitarian
# 13    1.78         3                 Episcopalian
# 14    1.83         0                 Presbyterian
# 15    1.93         4       unaffiliated Christian
# 16    1.78         5       unaffiliated Christian
# 17    1.73         4                    Methodist
# 18    1.73         8                    Methodist
# 19    1.83         7          Disciples of Christ
# 20    1.88         3                 Episcopalian
# 21    1.80         5          Disciples of Christ
# 22    1.68         3                 Presbyterian
# 23    1.80         5                 Presbyterian
# 24    1.70         2                    Methodist
# 25    1.78         6               Dutch Reformed
# 26    1.83         3                    Unitarian
# 27    1.80         3                 Presbyterian
# 28    1.83         0                      Baptist
# 29    1.78         2            Congregationalist
# 30    1.80         2  Society of Friends (Quaker)
# 31    1.88         6                 Episcopalian
# 32    1.75         1                      Baptist
# 33    1.78         2                 Presbyterian
# 34    1.83         3               Roman Catholic
# 35    1.92         2          Disciples of Christ
# 36    1.80         2  Society of Friends (Quaker)
# 37    1.83         4                 Episcopalian
# 38    1.77         4                      Baptist
# 39    1.85         4             Christian Church
# 40    1.88         6                 Episcopalian
# 41    1.88         1                      Baptist
# 42    1.82         2                    Methodist
# 43    1.87         2       unaffiliated Christian
# 44    1.88         5                 Presbyterian
# 45    1.82         3               Roman Catholic
# 46    1.88         5                 Presbyterian
#
#                   Higher Education                         Occupation  ...  \
# 0                              NaN          Plantation Owner, Soldier  ...
# 1                          Harvard                     Lawyer, Farmer  ...
# 2      College of William and Mary         Inventor,Lawyer, Architect  ...
# 3                        Princeton           Plantation Owner, Lawyer  ...
# 4      College of William and Mary           Plantation Owner, Lawyer  ...
# 5                          Harvard                   Lawyer, Diplomat  ...
# 6                              NaN                    Soldier, Lawyer  ...
# 7                              NaN                             Lawyer  ...
# 8           Hampden-Sydney College                            Soldier  ...
# 9      College of William and Mary                             Lawyer  ...
# 10    University of North Carolina           Lawyer, Plantation Owner  ...
# 11                             NaN                            Soldier  ...
# 12                             NaN                             Lawyer  ...
# 13                 Bowdoin College                             Lawyer  ...
# 14               Dickinson College                   Lawyer, Diplomat  ...
# 15                             NaN              Land Surveyor, Lawyer  ...
# 16                             NaN                             Tailor  ...
# 17          U.S.  Military Academy      Soldier (General of the Army)  ...
# 18         Kenyon College, Harvard                             Lawyer  ...
# 19                Williams College  School Teacher, Minister, Soldier  ...
# 20                   Union College       Customs Collector of NY port  ...
# 21                             NaN           Sheriff, Lawyer, Teacher  ...
# 22                Miami University                 Lawyer, Journalist  ...
# 23                             NaN           Sheriff, Lawyer, Teacher  ...
# 24    Allegheny College,Albany Law                             Lawyer  ...
# 25               Harvard, Columbia   Public Official, Rancher, Author  ...
# 26  University of Cincinnati, Yale          Judge, Dean of Law School  ...
# 27           Princeton, J. Hopkins     Professor, Political scientist  ...
# 28            Ohio Central College         Newspaper Publisher/Editor  ...
# 29                 Amherst College                     Lawyer, Banker  ...
# 30             Stanford University                           Engineer  ...
# 31               Harvard, Columbia                             Lawyer  ...
# 32                             NaN    Farmer, Men'S Clothing Retailer  ...
# 33           U.S. Military Academy                   Soldier, General  ...
# 34               Harvard, Stanford          U.S. Navy Officer, Author  ...
# 35         Texas State, Georgetown           Teacher, Public Official  ...
# 36      Whittier College, Duke Law            Lawyer, Public Official  ...
# 37    University of Michigan, Yale            Lawyer, Public Official  ...
# 38                US Naval Academy        Navy Officer, Peanut Farmer  ...
# 39                  Eureka College                Actor, Union leaser  ...
# 40                 Yale University                  Businessman (Oil)  ...
# 41        Georgetown, Yale, Oxford               Lawyer, Law Lecturer  ...
# 42                   Yale, Harvard       Businessman (Oil, Baseball)   ...
# 43               Columbia, Harvard                      Law Professor  ...
# 44           Fordham, Pennsylvania                        Real estate  ...
# 45     Syracuse University College                             Lawyer  ...
# 46           Fordham, Pennsylvania                        Real estate  ...
#
#                           Vice President               Previous Office  \
# 0                             John Adams            Commander-in-Chief
# 1                       Thomas Jefferson     1st Vice President of USA
# 2             Aaron Burr, George Clinton     2nd Vice President of USA
# 3         George Clinton, Elbridge Gerry            Secretary of State
# 4                        Daniel Tompkins              Secretary of War
# 5                           John Calhoun            Secretary of State
# 6         John Calhoun, Martin van Buren  Military Governor of Florida
# 7                        Richard Johnson     8th Vice President of USA
# 8                             John Tyler          Minister to Colombia
# 9                                   none    10th Vice President of USA
# 10                         George Dallas         Governor of Tennessee
# 11                      Millard Fillmore      Major General, U.S. Army
# 12                                  none    12th Vice President of USA
# 13                          William King          Senator (NH) 1837-42
# 14                     John Breckinridge            Minister to the UK
# 15       Hannibal Hamlin, Andrew Johnson        Congressman (Illinois)
# 16                                  none    16th Vice President of USA
# 17         Schuyler Colfax, Henry Wilson   Commanding General of  Army
# 18                       William Wheeler              Governor of Ohio
# 19                        Chester Arthur            Congressman (Ohio)
# 20                                  none    20th Vice President of USA
# 21                      Thomas Hendricks          Governor of New York
# 22                           Levi Morton             Senator (Indiana)
# 23                       Adlai Stevenson         22nd President of USA
# 24         Garret Hobart , Th. Roosevelt              Governor of Ohio
# 25                     Charles Fairbanks    25th Vice President of USA
# 26                         James Sherman     10th Chief Justice of USA
# 27                       Thomas Marshall        Governor of New Jersey
# 28                       Calvin Coolidge                Senator (Ohio)
# 29                         Charles Dawes    29th Vice President of USA
# 30                        Charles Curtis         Secretary of Commerce
# 31  John Garner , Henry Wallace,  Truman          Governor of New York
# 32                         Alben Barkley    34th Vice President of USA
# 33                 Richard Milhous Nixon  Sup. Allied Commander Europe
# 34                        Lyndon Johnson                 Senator ( MA)
# 35                       Hubert Humphrey    37th Vice President of USA
# 36          Spiro Agnew , Gerald R. Ford    36th Vice President of USA
# 37                    Nelson Rockefeller    40th Vice President of USA
# 38                        Walter Mondale           Governor of Georgia
# 39                     George H. W. Bush        Governor of California
# 40                 James Danforth Quayle    43rd Vice President of USA
# 41                               Al Gore          Governor of Arkansas
# 42                        Richard Cheney             Governor of Texas
# 43                          Joseph Biden            Senator (Illinois)
# 44                      Michael R. Pence                          none
# 45                         Kamala Harris    47th Vice President of USA
# 46                              JD Vance         45th President of USA
#
#                                               Economy  \
# 0   [' Hamilton established BUS', '1792 Coinage Ac...
# 1   ['1798 Progressive land value tax of up to 1% ...
# 2   ['1807 Embargo Act forbidding foreign trade in...
# 3   [' The first U.S. protective tariff was impose...
# 4   ['1819 Panic of 1819 (too much land speculatio...
# 5   [' "Internal improvements" program (roads, por...
# 6   ['1832 The Bank War. Veto for rechartering of ...
# 7   ['1837 The Panic of 1837. Financial crisis & d...
# 8                                            ['None']
# 9   ['Economic crisis initiated by the Panic of 18...
# 10    ['1846 Walker Tariff. Taxes reduced and fixed']
# 11                                           ['None']
# 12  ['Expanding trade while limiting American comm...
# 13                         ['Reforming the Treasury']
# 14  ['1857 Tariff of 1857. Reduction. North compla...
# 15                                           ['None']
# 16               ['Reconstruction plan in the south']
# 17  ['1873 Depression & financial crisis', ' Resum...
# 18  ['1878 Bland-Allison Act - Treasury buys silve...
# 19                ['1881 Refinance of national debt']
# 20  ['1885 Tariff of 1875 continued protectionist ...
# 21  [' Ended coinage based on silver', '1888 Mills...
# 22  ['1890 Pension Act - money to the veterans', '...
# 23  ['1893 Panic of 1893 and depression.', '1893 S...
# 24  ['1897 Dingley Tariff. Highest ever.', '1900 G...
# 25  ['1907 Panic of 1907 ("Roosevelt Panic")', '19...
# 26  ['1909 Payne-Aldrich Tariff. Unpopular. Duties...
# 27  ['1913 Federal Reserve Act', '1913 Underwood T...
# 28  [' Tax cuts for the rich and the end of antitr...
# 29  [' "Roaring Twenties"-Rapid economic growth', ...
# 30  ['1929 Stock Market Crash', ' The Great Depres...
# 31  ['1933 Glass-Steagall Act to protect bank acco...
# 32  ['1946  Veto on Taft-Hartley Act regulating st...
# 33  ['1956 Federal-Aid Highway Act - National high...
# 34  [' “New Frontier”: Tax reduction and other ref...
# 35  ['1964 Revenue Act &  Economic Opportunity Act...
# 36                 ['1973 OPEC embargo & Oil crisis']
# 37  [' Recession & Inflation. The worst economy si...
# 38  ['1979 Beer market deregulation', '1978 Airlin...
# 39  [' "Reaganomics": tax cuts, gov’t downsizing',...
# 40  [' Increased taxes despite his campaign promis...
# 41  ['1993-2001 Sustained economic growth and succ...
# 42  ['2001, 2003 Bush Tax cuts', '2008 Financial c...
# 43  ['2009 Economic Stimulus: Signed $787 bn for R...
# 44  [' Permanent cuts to the corporate tax rate, f...
# 45  ['Postal Service Reform Act of 2022', 'Signed ...
# 46                                                NaN
#
#                                       Foreign Affairs  \
# 0   ['1793 Neutrality in the France-Britain confli...
# 1   ['1797 the XYZ Affair: a bribe of French agent...
# 2   ['1805 Peace Treaty with Tripoli. Piracy stopp...
# 3   ['1814 The Treaty of Ghent ends the War of 1812']
# 4   ['1823 Monroe Doctrine', '1818 49th parallel s...
# 5   ['Unsuccessful attempt to purchase Texas from ...
# 6                        [' Texas wins independence']
# 7   [' Recognition of Republic of Texas; annex avo...
# 8                                            ['None']
# 9   ['1842 Webster–Ashburton Treaty settles border...
# 10  ['1846 Agreement with Britain over Oregon. Bot...
# 11  ['1850 Clayton–Bulwer Treaty with Britain: no ...
# 12  [' Commodore Matthew C. Perry was sent to open...
# 13  ['1854 Ostend Manifesto. Crisis over a leaked ...
# 14  ['Strengthening the influence of the United St...
# 15  ['Lincoln left the diplomatic issues in the ha...
# 16                       ['1867 Treaty with Russia.']
# 17  ['1871 Treaty of Washington', '1875 Free trade...
# 18  ['1877 Granted the Army the power to pursue ba...
# 19  ['Call for a Pan-American conference to mediat...
# 20  [' Treaty with Nicaragua to build a canal viol...
# 21  [' Refused to promote the previous administrat...
# 22       ['1889 Formation of the Pan-American union']
# 23  ['1895 Controversy with Britain over Venezuela...
# 24  ['1899 Treaty of Paris. U.S. becomes a colonia...
# 25  ['1903 Orchestrated Panama independence. Panam...
# 26  [" 'Dollar Diplomacy' ; State dept. coordinate...
# 27  ['1919 Treaty of Versailles after WW I, "14 po...
# 28  ['1921  Knox–Porter Resolution: official end o...
# 29  ['1928 Kellogg-Briand Pact (renouncement of wa...
# 30  ['1932 Stimson Doctrine: US would not recogniz...
# 31  ['1935 Lend-Lease Act, allowing  US to aid All...
# 32  ['1945 Potsdam Conference', '1947 Truman Doctr...
# 33  ['1954 Geneva Conference (SEATO)', '1956 Suez ...
# 34  ['1961 Vienna Summit', '1961  Alliance for Pro...
# 35                         ['1968 Paris Peace Talks']
# 36  ['1971 Nixon visits China; "Ping Pong diplomac...
# 37  ['1975 Evacuation of US embassy in Saigon', '1...
# 38  ['1979 Camp-David Accords between Israel and E...
# 39  ['1983 Strategic Defense Initiative ("Star War...
# 40  ['1989 Berlin Wall falls.', '1991 Dissolution ...
# 41  ['1993 Oslo accords; Isr./PLO', '1995 Dayton B...
# 42  [' Iraq’ s "Weapons of mass destruction"  hoax...
# 43  [" 'Leading from behind' stance in Mid East  g...
# 44  [' US abandon Paris Climate Accord and WHO', '...
# 45  ['2022-2023 Significant U.S. Military Assistan...
# 46                                                NaN
#
#                                     Military Activity  \
# 0                          ['1794 Whiskey Rebellion']
# 1   ['1798–1800 The Quasi war. Undeclared naval wa...
# 2   ['1801-05 Naval operation against Tripoli and ...
# 3   ['1811 Tippecanoe battle (Harrison vs. Chief T...
# 4   ['1817 1st Seminole war against Seminole India...
# 5                                            ['None']
# 6   ['1836 Alamo. 6000 Mexicans defeat 190 America...
# 7   ['1838 2nd Seminole war against Seminole India...
# 8                                            ['None']
# 9                ['1842 End of the 2nd Seminole war']
# 10  ['1846 American-Mexican war. Mexico city captu...
# 11                                           ['None']
# 12                                           ['None']
# 13                                           ['None']
# 14  ['1857 Utah War: 2500 soldiers were sent to ou...
# 15                            ['1863-1865 Civil War']
# 16                                           ['None']
# 17  ['1876 Battle of the Little Bighorn. Gen. Cust...
# 18  ['1877 Bear Paw Battle against Nez Perce India...
# 19                                           ['None']
# 20                      ['Start of the "Steel Navy"']
# 21  ['1886 Apache leader Geronimo  was chased & su...
# 22  ['1890 "Wounded knee" massacre. 150 Sioux Indi...
# 23  ['First ships of a navy capable of offensive a...
# 24  ['1898 Sinking of USS Maine', '1898 Spanish-US...
# 25  [' In spite of his militaristic attitudes, pea...
# 26  ['1912 2500 troops were sent to Nicaragua to p...
# 27  ['1915 Occupation of Dominican Rep.', '1916 US...
# 28  ['1923 Posey War (a small conflict with Americ...
# 29  ['1928 Clark Memorandum - concerned the United...
# 30  ['He thrice threatened intervention in the Dom...
# 31      ['1941 Pearl Harbor', '1941-45 World War II']
# 32  ['1945 Atomic bombs', '1945 End of WW II', '19...
# 33  ['1953 End of Korean War', '1958 USA troops in...
# 34  ['1963  “Advisers” attached to the South Vietn...
# 35  ['1965 Gulf of Tonkin Resolution - president g...
# 36  ['1970 Expansion of  war to Cambodia and Laos'...
# 37  ['1974 Official end of the Vietnam War', '1975...
# 38  ['1980 Revoked the Sino-American Mutual Defens...
# 39  ['1983 241 Marines, of a multinational force, ...
# 40  ['1989-90 Panama invasion. Noriega arrested', ...
# 41  ['1993 Mogadishu Battle : 2 Black Hawks down, ...
# 42  ['2001 War against the Afghanistan Talibans', ...
# 43  ['2011 Death of Osama bin Laden.', '2011 Iraq ...
# 44                ['2019 US Space Force is founded.']
# 45  ['Withdrawal from Afghanistan', '2022 Countert...
# 46                                                NaN
#
#                                          Other Events  \
# 0   ['1791 Bill of Rights', '1792 Post Office foun...
# 1   ['1798 Alien & Sedition Act to silence critics...
# 2   ['1803 The Louisiana purchase', '1804 12th Ame...
# 3   ['1811 Cumberland Road construction starts (fi...
# 4   ['1819 Florida ceded to US', "1820 Missouri Co...
# 5   [' Accused for "corrupt bargain" to obtain Cla...
# 6   ['1830 Indian Removal Act', "1832 South Caroli...
# 7   ['1838 "The Trail of Tears". Indians’ relocati...
# 8   ['1841 Delivered the longest inaugural address...
# 9   ['1841 His cabinet resigned after he vetoed ba...
# 10  ['1846 A large crack in the Liberty Bell.', '1...
# 11  [' The question of extending slavery to the ne...
# 12  ['1850 Compromise of 1850 and Fugitive Slave A...
# 13  ['1853 Gadsden Purchase. Land from Mexico.', '...
# 14  ['1857 Dred Scott decision: States can decide ...
# 15  ['1863 Emancipation Proclamation, freeing slav...
# 16  ['1865 Amnesty', '1867 Reconstruction Act & Of...
# 17  ['1871 Civil Service', '1870-71 Enforcement Ac...
# 18  ['1877 Reconstruction end. Army withdrew from ...
# 19  ['1881 On July 2, he was shot by Charles Juliu...
# 20      ['1883 Pendleton Act: Civil hiring on merit']
# 21  ['1886 Statue of Liberty', ' Curtailed largess...
# 22  ['1889 Opening of Oklahoma to 20,000 settlers'...
# 23                           ['1893 Pullman strike.']
# 24  ['1898 Yellow Journalism (Hyped Maine)', '1898...
# 25  [' Conservation becomes an issue. Creation of ...
# 26  [' Record antitrust suits', '1912 New states: ...
# 27  ['1916 Child labor curtailed', '1916 Federal F...
# 28  ['1921 Federal Highway Act  - the age of the "...
# 29  ['1924 Immigration Act limits immigrants from ...
# 30  ['1932 Reconstruction Finance Corporation to p...
# 31  ['1933 First 100 days legislation frenzy', '19...
# 32  ['1945 Fair Deal: health care, civil rights et...
# 33  [' Alaska and Hawaii admitted as states', '195...
# 34  ['1961 Peace Corps program', '1961 "Moon race"...
# 35  ['1964 The Civil Rights Act', '1964 Great Soci...
# 36  ['1969 Moon landing', '1970 Environment Act', ...
# 37  ['1974 Granted a pardon to  Nixon.', '1975 Air...
# 38  [' Pardoned  Vietnam War draft evaders', ' Ene...
# 39  ['1981 Assassination attempt by John W. Hinkle...
# 40  ['1990 Americans with Disabilities Act', '1990...
# 41  ["1993 “Don't ask, don't tell”- gays in the mi...
# 42  ['2001 9/11', '2001 Patriot Act', '2002 “no ch...
# 43  ['2010 Healthcare reform: Affordable Care Act ...
# 44  ['2020 Covid-19 pandemic', ' Impeached twice',...
# 45  ['Biden pledged to double climate funding to d...
# 46                                                NaN
#
#                                                Legacy Starting Year  \
# 0   He is universally regarded as one of the great...          1789
# 1   One of the most experienced men ever to become...          1797
# 2   Probably  the most intelligent man ever to occ...          1801
# 3   His leadership in the War of 1812 was particul...          1809
# 4   His presidency contributed to national defense...          1817
# 5   He had been an excellent Secretary of State, m...          1825
# 6   Historians see in him both the best and the wo...          1829
# 7   An able man, but always regarded more as a shr...          1837
# 8                                                none          1841
# 9   His presidency is held in low esteem but score...          1841
# 10  Polk added more territory than had any other p...          1845
# 11  His blunt manner and unsophisticated style han...          1849
# 12  Honest and hardworking but a pompous, colorles...          1850
# 13  As president, he made many divisive decisions ...          1853
# 14  His administration was dominated by fighting b...          1857
# 15  The greatest U.S. President. He won the Civil ...          1861
# 16  His conflict with Congress and his impeachment...          1865
# 17  An excellent general but a mediocre politician...          1869
# 18  An  effective president, ending military occup...          1877
# 19  In the 4 months before he was shot, he did not...          1881
# 20  Despite his reputation as a leading spoilsmen ...          1881
# 21  He won praise for his honesty, independence, i...          1885
# 22   He was an effective leader but the economy de...          1889
# 23  His reforms made him an icon for conservatives...          1893
# 24  His leadership and his actions affected profou...          1897
# 25  The first modern American president and one of...          1901
# 26  A good administrator but without exceptional p...          1909
# 27  Effective leadership in instituting a progress...          1913
# 28  Presided over one of the most corrupt administ...          1921
# 29  A competent administrator and a shrewd politic...          1923
# 30  A qualified executive who failed to provide ef...          1929
# 31  The longest and one of the most acclaimed pres...          1933
# 32  Unexpectedly a very efficient replacement. Sha...          1945
# 33  After a glorious military career, as president...          1953
# 34  His youth, vigor, and style brought a fresh ai...          1961
# 35  Passed his Great Society domestic programs and...          1963
# 36  Although he ended U.S. involvement in the Viet...          1969
# 37  A congressional president whose historic role ...          1974
# 38  Intelligent and hardworking but a DC outsider....          1977
# 39  While his aptitude for the job was often quest...          1981
# 40  He took few domestic initiatives and the econo...          1989
# 41  The longest period of peacetime economic expan...          1993
# 42  He left as one of the least popular and most d...          2001
# 43   Important changes on healthcare, education, c...          2009
# 44  Polarizing leadership style, controversial pol...          2017
# 45  Focused on pandemic response, economic recover...          2021
# 46                                                NaN          2025
#
#    Ending Year Term Length
# 0         1797           8
# 1         1801           4
# 2         1809           8
# 3         1817           8
# 4         1825           8
# 5         1829           4
# 6         1837           8
# 7         1841           4
# 8         1841           0
# 9         1845           4
# 10        1849           4
# 11        1850           1
# 12        1853           3
# 13        1857           4
# 14        1861           4
# 15        1865           4
# 16        1869           4
# 17        1877           8
# 18        1881           4
# 19        1881           0
# 20        1885           4
# 21        1889           4
# 22        1893           4
# 23        1897           4
# 24        1901           4
# 25        1909           8
# 26        1913           4
# 27        1921           8
# 28        1923           2
# 29        1929           6
# 30        1933           4
# 31        1945          12
# 32        1953           8
# 33        1961           8
# 34        1963           2
# 35        1969           6
# 36        1974           5
# 37        1977           3
# 38        1981           4
# 39        1989           8
# 40        1993           4
# 41        2001           8
# 42        2009           8
# 43        2017           8
# 44        2021           4
# 45        2025           4
# 46        <NA>        <NA>
#
# [47 rows x 23 columns]

# %% [markdown]
# ## 2) Pull and annualize macroeconomic indicators
#
# Each series is pulled from FRED and then averaged to yearly values for easier term-level comparisons.

# %%
def load_annual_series(series_id: str, start: str, value_name: str | None = None) -> pd.DataFrame:
    series = pdr.DataReader(series_id, "fred", start=start)
    if value_name and value_name != series_id:
        series = series.rename(columns={series_id: value_name})
    series["YEAR"] = series.index.year
    return series.groupby("YEAR").mean()


gdp = load_annual_series("GDP", "1947-01-01")
unemployment = load_annual_series("UNRATE", "1948-01-01")
population = load_annual_series("POP", "1952-01-01")
gini = load_annual_series("SIPOVGINIUSA", "1967-01-01", value_name="GINI")
labor_force = load_annual_series("CIVPART", "1948-01-01")
interest_rate = load_annual_series("DFF", "1954-01-01")
surplus_deficit = load_annual_series("FYFSD", "1947-01-01")
cpi = load_annual_series("CPIAUCSL", "1947-01-01", value_name="CPI")
pce = load_annual_series("PCEPI", "1947-01-01", value_name="PCE")

macro_frames = [
    gdp,
    unemployment,
    population,
    gini,
    labor_force,
    interest_rate,
    surplus_deficit,
    cpi,
    pce,
]

# %% [markdown]
# ## 3) Merge macro data to presidential terms and compute changes
#
# This step matches each indicator to the term start/end year and calculates absolute and percent changes.

# %%
merged_data = p_df.copy()
for frame in macro_frames:
    merged_data = merged_data.merge(frame, left_on="Starting Year", right_index=True, how="left")

merged_data = merged_data.rename(
    columns={
        "FYFSD": "Starting Surplus/Deficit",
        "GINI": "Starting Gini",
        "DFF": "Starting Interest Rate",
        "GDP": "Starting GDP",
        "UNRATE": "Starting Unemployment",
        "POP": "Starting Population",
        "CIVPART": "Starting Labor Force",
        "CPI": "Starting CPI",
        "PCE": "Starting PCE",
    }
)

series_lookup = {
    "Surplus/Deficit": (surplus_deficit, "FYFSD"),
    "Gini": (gini, "GINI"),
    "Interest Rate": (interest_rate, "DFF"),
    "GDP": (gdp, "GDP"),
    "Unemployment": (unemployment, "UNRATE"),
    "Population": (population, "POP"),
    "Labor Force": (labor_force, "CIVPART"),
    "CPI": (cpi, "CPI"),
    "PCE": (pce, "PCE"),
}

term_length = merged_data["Term Length"].replace({0: np.nan})

for metric, (frame, source_col) in series_lookup.items():
    start_col = f"Starting {metric}"
    end_col = f"Ending {metric}"
    delta_col = f"Change in {metric} Δ"
    pct_col = f"Change in {metric} %"
    annualized_col = f"Annualized Change in {metric} %"

    merged_data[end_col] = merged_data["Ending Year"].map(frame[source_col])
    merged_data[delta_col] = merged_data[end_col] - merged_data[start_col]
    merged_data[pct_col] = (merged_data[delta_col] / merged_data[start_col]) * 100
    merged_data[annualized_col] = np.where(
        (merged_data[start_col] > 0) & (merged_data[end_col] > 0) & (term_length > 0),
        ((merged_data[end_col] / merged_data[start_col]) ** (1 / term_length) - 1) * 100,
        np.nan,
    )

merged_data["Surplus/Deficit Ranking"] = merged_data["Change in Surplus/Deficit Δ"].rank(ascending=False)

merged_data["GDP per Capita Starting"] = (merged_data["Starting GDP"] / merged_data["Starting Population"]) * 1_000_000
merged_data["GDP per Capita Ending"] = (merged_data["Ending GDP"] / merged_data["Ending Population"]) * 1_000_000
merged_data["Change in GDP per Capita Δ"] = merged_data["GDP per Capita Ending"] - merged_data["GDP per Capita Starting"]
merged_data["Change in GDP per Capita %"] = (
    merged_data["Change in GDP per Capita Δ"] / merged_data["GDP per Capita Starting"]
) * 100
merged_data["Annualized Change in GDP per Capita %"] = np.where(
    (merged_data["GDP per Capita Starting"] > 0) & (merged_data["GDP per Capita Ending"] > 0) & (term_length > 0),
    ((merged_data["GDP per Capita Ending"] / merged_data["GDP per Capita Starting"]) ** (1 / term_length) - 1) * 100,
    np.nan,
)

# %% [markdown]
# ## 4) Build ranked comparison tables

# %%
gdp_ranked = merged_data.sort_values("Change in GDP %", ascending=False).dropna(subset=["Change in GDP %"])
gdp_ranked = gdp_ranked[
    ["Name", "Term", "Term Length", "Starting GDP", "Ending GDP", "Change in GDP Δ", "Change in GDP %", "Annualized Change in GDP %"]
]

gdp_per_capita_ranked = merged_data.sort_values("Change in GDP per Capita %", ascending=False).dropna(
    subset=["Change in GDP per Capita %"]
)
gdp_per_capita_ranked = gdp_per_capita_ranked[
    [
        "Name",
        "Term",
        "Term Length",
        "GDP per Capita Starting",
        "GDP per Capita Ending",
        "Change in GDP per Capita Δ",
        "Change in GDP per Capita %",
        "Annualized Change in GDP per Capita %",
    ]
]

gini_ranked = merged_data.sort_values("Change in Gini %", ascending=True).dropna(subset=["Change in Gini %"])
gini_ranked = gini_ranked[
    ["Name", "Term", "Term Length", "Starting Gini", "Ending Gini", "Change in Gini Δ", "Change in Gini %", "Annualized Change in Gini %"]
]

unemployment_ranked = merged_data.sort_values("Change in Unemployment %", ascending=True).dropna(
    subset=["Change in Unemployment %"]
)
unemployment_ranked = unemployment_ranked[
    [
        "Name",
        "Term",
        "Term Length",
        "Starting Unemployment",
        "Ending Unemployment",
        "Change in Unemployment Δ",
        "Change in Unemployment %",
        "Annualized Change in Unemployment %",
    ]
]

labor_force_ranked = merged_data.sort_values("Change in Labor Force %", ascending=False).dropna(
    subset=["Change in Labor Force %"]
)
labor_force_ranked = labor_force_ranked[
    [
        "Name",
        "Term",
        "Term Length",
        "Starting Labor Force",
        "Ending Labor Force",
        "Change in Labor Force Δ",
        "Change in Labor Force %",
        "Annualized Change in Labor Force %",
    ]
]

cpi_ranked = merged_data.sort_values("Change in CPI %", ascending=True).dropna(subset=["Change in CPI %"])
cpi_ranked = cpi_ranked[
    ["Name", "Term", "Term Length", "Starting CPI", "Ending CPI", "Change in CPI Δ", "Change in CPI %", "Annualized Change in CPI %"]
]

pce_ranked = merged_data.sort_values("Change in PCE %", ascending=True).dropna(subset=["Change in PCE %"])
pce_ranked = pce_ranked[
    ["Name", "Term", "Term Length", "Starting PCE", "Ending PCE", "Change in PCE Δ", "Change in PCE %", "Annualized Change in PCE %"]
]

# %% [markdown]
# ## 5) Review outputs

# %%
top_n = TOP_N

rank_tables = {
    "GDP": gdp_ranked,
    "GDP per Capita": gdp_per_capita_ranked,
    "Gini (Lower Better)": gini_ranked,
    "Unemployment (Lower Better)": unemployment_ranked,
    "Labor Force": labor_force_ranked,
    "CPI Inflation (Lower Better)": cpi_ranked,
    "PCE Inflation (Lower Better)": pce_ranked,
}

top5_summary = pd.concat(
    [
        table[["Name", "Term"]].head(top_n).reset_index(drop=True).rename(
            columns={"Name": f"{label} - Name", "Term": f"{label} - Term"}
        )
        for label, table in rank_tables.items()
    ],
    axis=1,
)

top5_summary
# Out:
#        GDP - Name GDP - Term GDP per Capita - Name GDP per Capita - Term  \
# 0   Ronald Reagan  1981-1989         Ronald Reagan             1981-1989
# 1  Lyndon Johnson  1963-1969        Lyndon Johnson             1963-1969
# 2    Bill Clinton  1993-2001          Jimmy Carter             1977-1981
# 3    Jimmy Carter  1977-1981         Richard Nixon             1969-1974
# 4   Richard Nixon  1969-1974          Bill Clinton             1993-2001
#
#   Gini (Lower Better) - Name Gini (Lower Better) - Term  \
# 0               Donald Trump                  2017-2021
# 1              Richard Nixon                  1969-1974
# 2               Jimmy Carter                  1977-1981
# 3             Gerald R. Ford                  1974-1977
# 4             George W. Bush                  2001-2009
#
#   Unemployment (Lower Better) - Name Unemployment (Lower Better) - Term  \
# 0                       Barack Obama                          2009-2017
# 1                     Lyndon Johnson                          1963-1969
# 2                       Bill Clinton                          1993-2001
# 3                      Ronald Reagan                          1981-1989
# 4                          Joe Biden                          2021-2025
#
#   Labor Force - Name Labor Force - Term CPI Inflation (Lower Better) - Name  \
# 0      Ronald Reagan          1981-1989                     John F. Kennedy
# 1       Jimmy Carter          1977-1981                        Donald Trump
# 2     Lyndon Johnson          1963-1969                   Dwight Eisenhower
# 3      Richard Nixon          1969-1974                        Barack Obama
# 4     Gerald R. Ford          1974-1977                   George H. W. Bush
#
#   CPI Inflation (Lower Better) - Term PCE Inflation (Lower Better) - Name  \
# 0                           1961-1963                     John F. Kennedy
# 1                           2017-2021                        Donald Trump
# 2                           1953-1961                        Barack Obama
# 3                           2009-2017                   George H. W. Bush
# 4                           1989-1993                        Bill Clinton
#
#   PCE Inflation (Lower Better) - Term
# 0                           1961-1963
# 1                           2017-2021
# 2                           2009-2017
# 3                           1989-1993
# 4                           1993-2001

# %%
import dataframe_image as dfi
from pandas.io.formats.style import Styler

def ensure_styler(table, formatter: dict[str, str], precision: int = 2):
    base_table = table.data if isinstance(table, Styler) else table
    return base_table.style.format(precision=precision, formatter=formatter)

def export_ranked_tables(ranked_tables: dict[str, Styler], export_dir: Path, table_conversion: str) -> list[str]:
    export_dir.mkdir(parents=True, exist_ok=True)
    exported_files: list[str] = []

    for table_name, table in ranked_tables.items():
        safe_name = table_name.replace(" ", "_").replace("/", "_")
        output_path = export_dir / f"{safe_name}.png"
        dfi.export(table, str(output_path), table_conversion=table_conversion)
        exported_files.append(str(output_path))

    return exported_files

formatters = {
    "GDP": {"Change in GDP %": "{:.2f}%", "Annualized Change in GDP %": "{:.2f}%"},
    "GDP per Capita": {
        "Change in GDP per Capita %": "{:.2f}%",
        "Annualized Change in GDP per Capita %": "{:.2f}%",
    },
    "Gini (Lower Better)": {"Change in Gini %": "{:.2f}%", "Annualized Change in Gini %": "{:.2f}%"},
    "Unemployment (Lower Better)": {
        "Change in Unemployment %": "{:.2f}%",
        "Annualized Change in Unemployment %": "{:.2f}%",
    },
    "Labor Force": {
        "Change in Labor Force %": "{:.2f}%",
        "Annualized Change in Labor Force %": "{:.2f}%",
    },
    "CPI Inflation (Lower Better)": {"Change in CPI %": "{:.2f}%", "Annualized Change in CPI %": "{:.2f}%"},
    "PCE Inflation (Lower Better)": {"Change in PCE %": "{:.2f}%", "Annualized Change in PCE %": "{:.2f}%"},
}

base_ranked_tables = {
    "GDP": gdp_ranked,
    "GDP per Capita": gdp_per_capita_ranked,
    "Gini (Lower Better)": gini_ranked,
    "Unemployment (Lower Better)": unemployment_ranked,
    "Labor Force": labor_force_ranked,
    "CPI Inflation (Lower Better)": cpi_ranked,
    "PCE Inflation (Lower Better)": pce_ranked,
}

ranked_tables = {
    table_name: ensure_styler(base_ranked_tables[table_name], formatters[table_name])
    for table_name in base_ranked_tables
}

gdp_ranked = ranked_tables["GDP"]
gdp_per_capita_ranked = ranked_tables["GDP per Capita"]
gini_ranked = ranked_tables["Gini (Lower Better)"]
unemployment_ranked = ranked_tables["Unemployment (Lower Better)"]
labor_force_ranked = ranked_tables["Labor Force"]
cpi_ranked = ranked_tables["CPI Inflation (Lower Better)"]
pce_ranked = ranked_tables["PCE Inflation (Lower Better)"]

exported_files = export_ranked_tables(
    ranked_tables=ranked_tables,
    export_dir=EXPORT_DIR,
    table_conversion=TABLE_CONVERSION,
)

exported_files
# Out:
# ['exports\\GDP.png',
#  'exports\\GDP_per_Capita.png',
#  'exports\\Gini_(Lower_Better).png',
#  'exports\\Unemployment_(Lower_Better).png',
#  'exports\\Labor_Force.png',
#  'exports\\CPI_Inflation_(Lower_Better).png',
#  'exports\\PCE_Inflation_(Lower_Better).png']

# %%
gdp_per_capita_ranked

# %% [markdown]
# ## 6) Export artifacts
#
# Running Cell 13 exports one PNG per ranked table to `exports/`.
# This step is safe to run repeatedly and will overwrite files with the same names.
